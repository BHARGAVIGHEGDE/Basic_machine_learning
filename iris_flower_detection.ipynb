# %% [markdown]
# <a href="https://colab.research.google.com/github/BHARGAVIGHEGDE/oasis-infobyte/blob/main/iris_flower_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORTING LIBRARIES

# %%
#importing all the required libraries for this project
import numpy as np
import matplotlib as mp
import seaborn as sb
import pandas as pd
from sklearn import metrics

# %% [markdown]
# LOADING THE DATASET

# %%
columns_name=['sepal length','sepal width','petal length','petal width','flower_class']
#load the data by reading the csv files
data=pd.read_csv('iris.data',names=columns_name)
#listing out all the 150 entries
data.head(150)
# Out:
#      sepal length  sepal width  petal length  petal width    flower_class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# VISUALIZATION OF DATASET

# %%
data.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#visualize the whole dataset
#pairplot function is used to plot multiple pairwise bivariate distributions in a dataset
sb.pairplot(data,hue='flower_class')

# %% [markdown]
# SEPERATING INPUT AND OUTPUT COLUMNS

# %%
data_values=data.values
input=data_values[:,0:4]
output=data_values[:,4]
print(input)
print(output)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.0 1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.0 3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.0 3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.0 1.4 0.1]
#  [4.3 3.0 1.1 0.1]
#  [5.8 4.0 1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.0 0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.0 3.0 1.6 0.2]
#  [5.0 3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.0 3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.1 1.5 0.1]
#  [4.4 3.0 1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.0 3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.0 3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.0 1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %% [markdown]
# SPLITTING THE DATA INTO TRAINING AND TESTING

# %%
from sklearn.model_selection import train_test_split
input_train,input_test,output_train,output_test=train_test_split(input,output,test_size=0.2)

# %% [markdown]
# TRAINING MODEL USING LOGISTIC REGRESSION ALGORITHM

# %%
from sklearn.linear_model import LogisticRegression
model1=LogisticRegression()
model1.fit(input_train,output_train)

# %% [markdown]
# ACCURACY OF MODEL

# %%
prediction=model1.predict(input_test)
#accuracy of model
from sklearn.metrics import accuracy_score
print(accuracy_score(output_test,prediction)*100)
# Out:
# 100.0

# %% [markdown]
# CLASSIFICATION REPORT

# %%
from sklearn.metrics import classification_report
print(classification_report(output_test,prediction))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      1.00      1.00         7
#  Iris-virginica       1.00      1.00      1.00        13
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# VERIFICATION OF CODE

# %%
new=np.array([[3,2,1,0.2],[4.9,2.2,3.8,1.1],[5.3,2.5,4.6,1.9]])
prediction1=model1.predict(new)
print("Prediction of Species: {}".format(prediction1))
# Out:
# Prediction of Species: ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
